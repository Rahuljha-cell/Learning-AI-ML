# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahuljha-cell/Learning-AI-ML/blob/main/Matplotlib_in_ML_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 10, 0.25)
y = x**4

plt.plot(x,y, color = "red", marker = "+", linewidth=2)
plt.show()

# %%
x = np.arange(0, 10, 0.25)
y = x**4
y2 = x**3

plt.plot(x,y, color = "red", label= "x^4")
plt.plot(x,y2, color = "blue", label= "x^3")
plt.ylabel("Y", fontsize = 15)
plt.xlabel("X", fontsize = 15)
plt.legend()
plt.show()

# %%
x = np.arange(0, 10, 0.25)
y = x**4
y2 = x**3

plt.plot(x,y, color = "red", label= "x^4")
plt.plot(x,y2, color = "blue", label= "x^3")
plt.ylabel("Y", fontsize = 15)
plt.xlabel("X", fontsize = 15)
plt.legend()
plt.title("PrepInsta Chart")
plt.axis([0, 15, 0,20000])
plt.text(10, 12500, "PrepInsta", fontsize = 15)
plt.grid()
plt.show()
